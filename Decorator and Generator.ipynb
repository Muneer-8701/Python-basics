# %% [markdown]
# ### Iterator and Generator
# Generator allow us to generate as we go along,Instead of holding everything in memory.The main difference is when generator function is compiled they become an object that support an iteration protocol.that means when they are called in your code they don't actually return a value and then exit

# %%
def cubes(n):
    for num in range(n):
        yield num**3

# %%
for x in cubes(5):
    print(x)
# Out:
# 0
# 1
# 8
# 27
# 64

# %%
# next()func allow us to access the next element in a sequence .

def simple_gen():
    for x in range(3):
        yield x

# %%
g = simple_gen()

# %%
print(next(g))
# Out:
# 0

# %%
print(next(g))
# Out:
# 1

# %%
print(next(g))
# Out:
# 2

# %%
#iter() func
s = 'hey'

for let in s:
    print(let)
# Out:
# h
# e
# y

# %%
next(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 next(s)
#
# TypeError: 'str' object is not an iterator

# %%
s_iter = iter(s)

# %%
next(s_iter)
# Out:
# 'h'

# %%
next(s_iter)
# Out:
# 'e'

# %%
next(s_iter)
# Out:
# 'y'

# %%
next(s_iter)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 next(s_iter)
#
# StopIteration:
